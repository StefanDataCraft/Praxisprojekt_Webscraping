# %%
# Die üblichen verdächtigen Imports
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup

url_anfang = 'https://books.toscrape.com/'

# Komplette Schleife für zehn nachfolgende Seiten (deluxe Version)
full_list = []
for p in range(1, 11):
    full_url = url_anfang + f'catalogue/page-{p}.html'
    response = requests.get(full_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    for book_box in soup.find_all("article", class_="product_pod"):
        title = book_box.find('h3').find('a')['title']
        rating = book_box.find('p')['class'][1]
        mytable = {"One": 1, "Two": 2, "Three": 3, "Four": 4, "Five": 5}
        num_rating = rating.translate(mytable)
        #num_rating = rating({"One": 1, "Two": 2, "Three": 3, "Four": 4, "Five": 5})
        #average_rating = df["Rating"].map({"One": 1, "Two": 2, "Three": 3, "Four": 4, "Five": 5}).mean()
        clean_price = price.replace("£","")
        full_list.append({"Title": title, "Rating": num_rating, "Price": clean_price})


print(full_list)
df = pd.DataFrame(full_list, columns=["Title", "Rating", "Price"])
df.to_csv("./book_data.csv", index=False)
# Out:
# [{'Title': 'A Light in the Attic', 'Rating': 'Three', 'Price': '42.16'}, {'Title': 'Tipping the Velvet', 'Rating': 'One', 'Price': '42.16'}, {'Title': 'Soumission', 'Rating': 'One', 'Price': '42.16'}, {'Title': 'Sharp Objects', 'Rating': 'Four', 'Price': '42.16'}, {'Title': 'Sapiens: A Brief History of Humankind', 'Rating': 'Five', 'Price': '42.16'}, {'Title': 'The Requiem Red', 'Rating': 'One', 'Price': '42.16'}, {'Title': 'The Dirty Little Secrets of Getting Your Dream Job', 'Rating': 'Four', 'Price': '42.16'}, {'Title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'Rating': 'Three', 'Price': '42.16'}, {'Title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'Rating': 'Four', 'Price': '42.16'}, {'Title': 'The Black Maria', 'Rating': 'One', 'Price': '42.16'}, {'Title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'Rating': 'Two', 'Price': '42.16'}, {'Title': "Shakespeare's Sonnets",
# ...
