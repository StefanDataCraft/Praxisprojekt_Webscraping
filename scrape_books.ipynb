# %%
# Die üblichen verdächtigen Imports
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup

url_anfang = 'https://books.toscrape.com/'

# Komplette Schleife für zehn nachfolgende Seiten (deluxe Version)
full_list = []
for p in range(1, 11):
    full_url = url_anfang + f'catalogue/page-{p}.html'
    response = requests.get(full_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    for book_box in soup.find_all("article", class_="product_pod"):
        title = book_box.find('h3').find('a')['title']
        rating = book_box.find('p')['class'][1]
        num_rating = str(map(rating,{"One": 1, "Two": 2, "Three": 3, "Four": 4, "Five": 5}))
        price = book_box.find('div', class_="product_price").find('p', "price_color").text
        clean_price = price.replace("£","")
        full_list.append({"Title": title, "Rating": num_rating, "Price": clean_price})


print(full_list)
df = pd.DataFrame(full_list, columns=["Title", "Rating", "Price"])
print(os.getcwd())
df.to_csv("./book_data.csv", index=False)
# Out:
# [{'Title': 'A Light in the Attic', 'Rating': '<map object at 0x000001F294BFC430>', 'Price': '51.77'}, {'Title': 'Tipping the Velvet', 'Rating': '<map object at 0x000001F2953F1CF0>', 'Price': '53.74'}, {'Title': 'Soumission', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '50.10'}, {'Title': 'Sharp Objects', 'Rating': '<map object at 0x000001F2953F01C0>', 'Price': '47.82'}, {'Title': 'Sapiens: A Brief History of Humankind', 'Rating': '<map object at 0x000001F294BFF970>', 'Price': '54.23'}, {'Title': 'The Requiem Red', 'Rating': '<map object at 0x000001F2953F1CF0>', 'Price': '22.65'}, {'Title': 'The Dirty Little Secrets of Getting Your Dream Job', 'Rating': '<map object at 0x000001F294BFC430>', 'Price': '33.34'}, {'Title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'Rating': '<map object at 0x000001F2953F01C0>', 'Price': '17.93'}, {'Title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '22.60'}, {'Title': 'The Black Maria', 'Rating': '<map object at 0x000001F2953F1CF0>', 'Price': '52.15'}, {'Title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'Rating': '<map object at 0x000001F294BFF970>', 'Price': '13.99'}, {'Title': "Shakespeare's Sonnets", 'Rating': '<map object at 0x000001F2953F01C0>', 'Price': '20.66'}, {'Title': 'Set Me Free', 'Rating': '<map object at 0x000001F294BFC430>', 'Price': '17.46'}, {'Title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'Rating': '<map object at 0x000001F2953F1CF0>', 'Price': '52.29'}, {'Title': 'Rip it Up and Start Again', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '35.02'}, {'Title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'Rating': '<map object at 0x000001F2953F01C0>', 'Price': '57.25'}, {'Title': 'Olio', 'Rating': '<map object at 0x000001F294BFF970>', 'Price': '23.88'}, {'Title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'Rating': '<map object at 0x000001F2953F1CF0>', 'Price': '37.59'}, {'Title': 'Libertarianism for Beginners', 'Rating': '<map object at 0x000001F294BFC430>', 'Price': '51.33'}, {'Title': "It's Only the Himalayas", 'Rating': '<map object at 0x000001F2953F01C0>', 'Price': '45.17'}, {'Title': 'In Her Wake', 'Rating': '<map object at 0x000001F294BFEE30>', 'Price': '12.84'}, {'Title': 'How Music Works', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '37.32'}, {'Title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'Rating': '<map object at 0x000001F294BFEE30>', 'Price': '30.52'}, {'Title': 'Chase Me (Paris Nights #2)', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '25.27'}, {'Title': 'Black Dust', 'Rating': '<map object at 0x000001F294BFEE30>', 'Price': '34.53'}, {'Title': 'Birdsong: A Story in Pictures', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '54.64'}, {'Title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'Rating': '<map object at 0x000001F294BFEE30>', 'Price': '22.50'}, {'Title': 'Aladdin and His Wonderful Lamp', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '53.13'}, {'Title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 'Rating': '<map object at 0x000001F294BFEE30>', 'Price': '40.30'}, {'Title': 'Wall and Piece', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '44.18'}, {'Title': 'The Four Agreements: A Practical Guide to Personal Freedom', 'Rating': '<map object at 0x000001F294BFEE30>', 'Price': '17.66'}, {'Title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'Rating': '<map object at 0x000001F294BFC640>', 'Price': '31.05'}, {'Title': 'The Elephant Tree', 'Rating': '<map object at 0x000001F294BFEE30>', 'Price': '23.82'}, { ...
# C:\repos\Praxisprojekt_Webscraping
